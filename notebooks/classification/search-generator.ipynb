# %%
# %load_ext autoreload
# %autoreload 2

# %%
from IPython.display import display
import plotly_express as px
import plotly.io as pio
pio.renderers.default = 'colab'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from preprocessing import stopwords, preprocess
from datasets import fake_br_corpus
# Out:
# [nltk_data] Downloading package stopwords to /home/aldo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
dataset = fake_br_corpus.loadTrain(True)

# %%
import joblib
model = joblib.load('models/SVM_rbf_20000feat_acc_0.909741')

# %%
from preprocessing.sentence_ranking_transformer import SentenceRankingTransformer
ranker = SentenceRankingTransformer(model, 'fake')

# %%
dataset['rankedText'] = ranker.fit_transform(dataset.text)

# %%
row = dataset.sample()
row.label
# Out:
# 3033    true
# Name: label, dtype: object

# %%
top32Words = ' '.join(
    row.rankedText.values[0].split(' ')[:32]
)

# %%
from IPython.display import HTML
HTML(f'<p>{row.text.values[0]}</p>')
# Out:
# <p>Feito na América, Amityville e Em defesa de Cristo chegam aos cinemas; G1 comenta em VÍDEO. Ação com Tom Cruise, terror e drama religioso são destaques do fim de semana. Cardápio de estreias também tem As duas Irenes, Deserto e Glory..  O astro Tom Cruise volta às telas em "Feito na América". Na história, o ator interpreta um piloto que também vende drogas e armas para o famoso cartel de Medellín, na Colômbia. Quando é recrutado para uma missão secreta nos Estados Unidos, vira um agente duplo. O cardápio de estreias deste fim de semana também traz o retorno da franquia "Amityville", que fez sucesso entre os anos 1970 e 90. Para os religiosos, "Em defesa de Cristo" conta a história de um jornalista ateu que investiga a existência de Deus. O G1 comenta as pincipais estreias da semana no VÍDEO acima; assista "As duas Irenes", "Deserto" e "Glory" são outros destaques. Leia mais sobre os filmes abaixo. O diretor</p>

# %%
HTML(f'<p>{top32Words}</p>')
# Out:
# <p>Feito na América, Amityville e Em defesa de Cristo chegam aos cinemas; G1 comenta em VÍDEO .  Leia mais sobre os filmes abaixo .  O diretor .  Ação com</p>
