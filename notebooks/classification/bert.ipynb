# %%
# %load_ext autoreload
# %autoreload ,2

# %%
from IPython.display import display
import plotly_express as px
import plotly.io as pio
pio.renderers.default = 'colab'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from preprocessing import stopwords, preprocess
from datasets import fake_br_corpus
# Out:
# [nltk_data] Downloading package stopwords to /home/aldo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
dataset = fake_br_corpus.loadTrain(True)

# %%
minSize =  2000#@param {type:"integer"}
row = dataset[dataset.numWords >= minSize].sample()
text, label = row[['text', 'label']].values[0]
len(text.split())
# Out:
# 2209

# %% [markdown]
# ---

# %%
import joblib

# %%
model=joblib.load('SVM_rbf_20000feat_acc_0.909741')

# %%
model.predict_proba(['aa aa'])
# Out:
# array([[0.58626043, 0.41373957]])
