# %%
# %load_ext autoreload
# %autoreload ,2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from IPython.display import display
import plotly_express as px
import plotly.io as pio
pio.renderers.default = 'colab'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from preprocessing import stopwords, preprocess
from datasets import fake_br_corpus

# %%
dataset = fake_br_corpus.loadTrain(True)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier

from sklearn.metrics import log_loss

pipeline = Pipeline([
    (
      'vect',
      TfidfVectorizer(
        stop_words=stopwords,
        preprocessor=preprocess,
        strip_accents=True,
      ),
    ), 
    ('clf', XGBClassifier()),
])

vectParameters = {
  'vect__ngram_range': ((1,3), (1,5), (1,7)),
  'vect__max_features': (1000, 5000, 10000, 20000),
  # 'vect__max_df': (0.5, 0.75, 1.0),
}

parameters = [        
    {
        **vectParameters,
        'clf': (XGBClassifier(),),
    },
    {
        **vectParameters,
        'clf': (SVC(probability=True),),
        'clf__C': (1, 0.75)
    },
    {
        **vectParameters,
        'clf': (RandomForestClassifier(),),
    },
]
grid_search = GridSearchCV(pipeline, parameters, verbose=10, scoring='accuracy', n_jobs=3)

# %%
result = grid_search.fit(dataset.text, dataset.label)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits

# %%
resultsDf = pd.DataFrame(result.cv_results_)
resultsDf
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      184.077742     11.026473         2.468164        1.494893
# 1      181.395806     25.525420         3.734855        3.228048
# 2      201.443858     10.317236         3.795097        2.017130
# 3      176.109461     12.137663         3.102641        1.932204
# 4      197.473554     20.229678         3.481816        0.898060
# 5      189.237339     13.512022         2.485047        1.423756
# 6      161.745294      7.166898         1.452008        0.595786
# 7      166.074143      8.720212         1.686515        0.667719
# 8      174.487346      4.504672         2.612982        1.487522
# 9      160.616892      9.685654         1.605494        0.868927
# 10     166.459239      7.920769         1.658691        1.148820
# 11     160.994970     18.192455         1.695920        0.587566
# 12      61.927780     22.595589         2.888748        0.540082
# 13      54.994997      5.767325         2.836631        0.620320
# 14      61.346293      6.436381         2.908604        0.669842
# 15     105.417843      6.014413         4.040179        0.903431
# 16     188.690703     18.054547         8.049947        1.564113
# 17     220.092788     23.396184         7.678745        0.971283
# 18     137.870783     32.045677         4.916467        1.052200
# 19     127.498058     14.201241         5.042617        0.929013
# 20     130.301511     13.721848         5.280196        1.035659
# 21     135.177001     13.815264         5.497436        1.016802
# 22     140.621381     15.163436         5.849913        1.101268
# 23     144.865475     14.353137         5.825954        1.109340
# 24      51.597670      4.701386         2.535079        0.465556
# 25      56.943042      7.160736         2.708787        0.778180
# 26      61.291944      7.598223         2.935141        0.455837
# 27      92.763743      8.412634         4.065373        0.668467
# 28      97.469623     10.786427         4.321957        0.814603
# 29     102.195889      9.836445         4.438122        0.921747
# 30     115.992558     13.124549         4.787628        0.695475
# 31     120.007917     12.596384         4.923962        0.759514
# 32     121.296433     11.646571         5.099998        1.240550
# 33     207.853399     25.352730        10.251483        1.664215
# 34     245.132736     60.189457         7.844817        1.262655
# 35     150.100381     16.517796         6.241742        1.601573
# 36      10.511252      0.975403         0.590938        0.255198
# 37      16.163238      2.283876         0.947199        0.395064
# 38      22.913979      2.536188         1.098233        0.431069
# 39      11.346159      1.467347         0.704803        0.459567
# 40      16.504298      2.198591         0.962802        0.351447
# 41      22.374699      2.889597         1.292629        0.684857
# 42      11.107432      1.432182         0.762159        0.415061
# 43      16.470644      2.239790         0.988688        0.399146
# 44      22.413241      3.121614         1.239471        0.602124
# 45      10.848334      1.572309         0.727689        0.418021
# 46      16.706181      2.095143         1.006390        0.469188
# 47      22.336322      3.456635         1.159899        0.432474
#
#                                             param_clf  \
# 0   XGBClassifier(base_score=None, booster=None, c...
# 1   XGBClassifier(base_score=None, booster=None, c...
# 2   XGBClassifier(base_score=None, booster=None, c...
# 3   XGBClassifier(base_score=None, booster=None, c...
# 4   XGBClassifier(base_score=None, booster=None, c...
# 5   XGBClassifier(base_score=None, booster=None, c...
# 6   XGBClassifier(base_score=None, booster=None, c...
# 7   XGBClassifier(base_score=None, booster=None, c...
# 8   XGBClassifier(base_score=None, booster=None, c...
# 9   XGBClassifier(base_score=None, booster=None, c...
# 10  XGBClassifier(base_score=None, booster=None, c...
# 11  XGBClassifier(base_score=None, booster=None, c...
# 12                         SVC(C=1, probability=True)
# 13                         SVC(C=1, probability=True)
# 14                         SVC(C=1, probability=True)
# 15                         SVC(C=1, probability=True)
# 16                         SVC(C=1, probability=True)
# 17                         SVC(C=1, probability=True)
# 18                         SVC(C=1, probability=True)
# 19                         SVC(C=1, probability=True)
# 20                         SVC(C=1, probability=True)
# 21                         SVC(C=1, probability=True)
# 22                         SVC(C=1, probability=True)
# 23                         SVC(C=1, probability=True)
# 24                         SVC(C=1, probability=True)
# 25                         SVC(C=1, probability=True)
# 26                         SVC(C=1, probability=True)
# 27                         SVC(C=1, probability=True)
# 28                         SVC(C=1, probability=True)
# 29                         SVC(C=1, probability=True)
# 30                         SVC(C=1, probability=True)
# 31                         SVC(C=1, probability=True)
# 32                         SVC(C=1, probability=True)
# 33                         SVC(C=1, probability=True)
# 34                         SVC(C=1, probability=True)
# 35                         SVC(C=1, probability=True)
# 36                           RandomForestClassifier()
# 37                           RandomForestClassifier()
# 38                           RandomForestClassifier()
# 39                           RandomForestClassifier()
# 40                           RandomForestClassifier()
# 41                           RandomForestClassifier()
# 42                           RandomForestClassifier()
# 43                           RandomForestClassifier()
# 44                           RandomForestClassifier()
# 45                           RandomForestClassifier()
# 46                           RandomForestClassifier()
# 47                           RandomForestClassifier()
#
#    param_vect__max_features param_vect__ngram_range param_clf__C  \
# 0                      1000                  (1, 3)          NaN
# 1                      1000                  (1, 5)          NaN
# 2                      1000                  (1, 7)          NaN
# 3                      5000                  (1, 3)          NaN
# 4                      5000                  (1, 5)          NaN
# 5                      5000                  (1, 7)          NaN
# 6                     10000                  (1, 3)          NaN
# 7                     10000                  (1, 5)          NaN
# 8                     10000                  (1, 7)          NaN
# 9                     20000                  (1, 3)          NaN
# 10                    20000                  (1, 5)          NaN
# 11                    20000                  (1, 7)          NaN
# 12                     1000                  (1, 3)            1
# 13                     1000                  (1, 5)            1
# 14                     1000                  (1, 7)            1
# 15                     5000                  (1, 3)            1
# 16                     5000                  (1, 5)            1
# 17                     5000                  (1, 7)            1
# 18                    10000                  (1, 3)            1
# 19                    10000                  (1, 5)            1
# 20                    10000                  (1, 7)            1
# 21                    20000                  (1, 3)            1
# 22                    20000                  (1, 5)            1
# 23                    20000                  (1, 7)            1
# 24                     1000                  (1, 3)         0.75
# 25                     1000                  (1, 5)         0.75
# 26                     1000                  (1, 7)         0.75
# 27                     5000                  (1, 3)         0.75
# 28                     5000                  (1, 5)         0.75
# 29                     5000                  (1, 7)         0.75
# 30                    10000                  (1, 3)         0.75
# 31                    10000                  (1, 5)         0.75
# 32                    10000                  (1, 7)         0.75
# 33                    20000                  (1, 3)         0.75
# 34                    20000                  (1, 5)         0.75
# 35                    20000                  (1, 7)         0.75
# 36                     1000                  (1, 3)          NaN
# 37                     1000                  (1, 5)          NaN
# 38                     1000                  (1, 7)          NaN
# 39                     5000                  (1, 3)          NaN
# 40                     5000                  (1, 5)          NaN
# 41                     5000                  (1, 7)          NaN
# 42                    10000                  (1, 3)          NaN
# 43                    10000                  (1, 5)          NaN
# 44                    10000                  (1, 7)          NaN
# 45                    20000                  (1, 3)          NaN
# 46                    20000                  (1, 5)          NaN
# 47                    20000                  (1, 7)          NaN
#
#                                                params  split0_test_score  \
# 0   {'clf': XGBClassifier(base_score=None, booster...           0.845775
# 1   {'clf': XGBClassifier(base_score=None, booster...           0.844955
# 2   {'clf': XGBClassifier(base_score=None, booster...           0.853979
# 3   {'clf': XGBClassifier(base_score=None, booster...           0.849877
# 4   {'clf': XGBClassifier(base_score=None, booster...           0.855619
# 5   {'clf': XGBClassifier(base_score=None, booster...           0.858901
# 6   {'clf': XGBClassifier(base_score=None, booster...           0.853158
# 7   {'clf': XGBClassifier(base_score=None, booster...           0.857260
# 8   {'clf': XGBClassifier(base_score=None, booster...           0.860541
# 9   {'clf': XGBClassifier(base_score=None, booster...           0.848236
# 10  {'clf': XGBClassifier(base_score=None, booster...           0.858080
# 11  {'clf': XGBClassifier(base_score=None, booster...           0.858901
# 12  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.870386
# 13  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.870386
# 14  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.871206
# 15  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.887613
# 16  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.887613
# 17  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.887613
# 18  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.887613
# 19  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.888433
# 20  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.888433
# 21  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.890894
# 22  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.888433
# 23  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.889253
# 24  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.870386
# 25  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.868745
# 26  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.869565
# 27  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.879409
# 28  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.881050
# 29  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.883511
# 30  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.887613
# 31  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.887613
# 32  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.887613
# 33  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.888433
# 34  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.887613
# 35  {'clf': SVC(C=1, probability=True), 'clf__C': ...           0.889253
# 36  {'clf': RandomForestClassifier(), 'vect__max_f...           0.843314
# 37  {'clf': RandomForestClassifier(), 'vect__max_f...           0.849877
# 38  {'clf': RandomForestClassifier(), 'vect__max_f...           0.847416
# 39  {'clf': RandomForestClassifier(), 'vect__max_f...           0.856440
# 40  {'clf': RandomForestClassifier(), 'vect__max_f...           0.858080
# 41  {'clf': RandomForestClassifier(), 'vect__max_f...           0.853158
# 42  {'clf': RandomForestClassifier(), 'vect__max_f...           0.854799
# 43  {'clf': RandomForestClassifier(), 'vect__max_f...           0.861362
# 44  {'clf': RandomForestClassifier(), 'vect__max_f...           0.861362
# 45  {'clf': RandomForestClassifier(), 'vect__max_f...           0.848236
# 46  {'clf': RandomForestClassifier(), 'vect__max_f...           0.859721
# 47  {'clf': RandomForestClassifier(), 'vect__max_f...           0.859721
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.894996           0.908121           0.889253
# 1            0.893355           0.910582           0.871206
# 2            0.891715           0.902379           0.886792
# 3            0.902379           0.910582           0.881050
# 4            0.893355           0.915505           0.881870
# 5            0.899098           0.912223           0.878589
# 6            0.894996           0.908942           0.881050
# 7            0.894176           0.909762           0.888433
# 8            0.890074           0.918786           0.886792
# 9            0.899098           0.915505           0.882691
# 10           0.898277           0.920427           0.885152
# 11           0.900738           0.911403           0.890894
# 12           0.902379           0.917966           0.908942
# 13           0.902379           0.917145           0.909762
# 14           0.902379           0.917966           0.908942
# 15           0.922067           0.926169           0.908942
# 16           0.920427           0.928630           0.911403
# 17           0.919606           0.927810           0.912223
# 18           0.931091           0.936833           0.915505
# 19           0.930271           0.937654           0.913864
# 20           0.928630           0.936833           0.916325
# 21           0.928630           0.938474           0.917966
# 22           0.926169           0.936833           0.919606
# 23           0.926989           0.936833           0.921247
# 24           0.896637           0.917145           0.907301
# 25           0.900738           0.916325           0.905660
# 26           0.900738           0.916325           0.902379
# 27           0.926169           0.922888           0.907301
# 28           0.922888           0.924528           0.907301
# 29           0.922067           0.922888           0.908121
# 30           0.926169           0.935193           0.910582
# 31           0.922067           0.935193           0.909762
# 32           0.923708           0.936013           0.911403
# 33           0.924528           0.937654           0.914684
# 34           0.920427           0.937654           0.915505
# 35           0.922067           0.937654           0.916325
# 36           0.871206           0.881050           0.850697
# 37           0.867925           0.876948           0.845775
# 38           0.867104           0.882691           0.853158
# 39           0.878589           0.887613           0.854799
# 40           0.875308           0.883511           0.853979
# 41           0.872026           0.883511           0.854799
# 42           0.881870           0.899918           0.858901
# 43           0.878589           0.894176           0.853979
# 44           0.880230           0.887613           0.863002
# 45           0.885972           0.899918           0.851518
# 46           0.874487           0.899918           0.860541
# 47           0.887613           0.889253           0.867104
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.836617         0.874953        0.028381               34
# 1            0.821839         0.868388        0.032024               36
# 2            0.823481         0.871669        0.029013               35
# 3            0.841544         0.877086        0.027499               33
# 4            0.856322         0.880534        0.022786               25
# 5            0.847291         0.879220        0.024154               29
# 6            0.848112         0.877252        0.023508               32
# 7            0.844828         0.878892        0.024108               30
# 8            0.841544         0.879547        0.026490               28
# 9            0.847291         0.878564        0.027207               31
# 10           0.839080         0.880203        0.028808               26
# 11           0.838259         0.880039        0.027285               27
# 12           0.845649         0.889064        0.026987               19
# 13           0.841544         0.888243        0.028277               20
# 14           0.839901         0.888079        0.028771               21
# 15           0.864532         0.901865        0.023003               15
# 16           0.864532         0.902521        0.023438               13
# 17           0.862890         0.902028        0.023737               14
# 18           0.868637         0.907936        0.026023                4
# 19           0.867816         0.907608        0.026102                5
# 20           0.867816         0.907608        0.025780                5
# 21           0.872742         0.909741        0.024389                1
# 22           0.871100         0.908428        0.024657                3
# 23           0.870279         0.908920        0.025050                2
# 24           0.838259         0.885946        0.028495               22
# 25           0.834975         0.885289        0.029739               23
# 26           0.834154         0.884632        0.029509               24
# 27           0.865353         0.900224        0.024025               16
# 28           0.862069         0.899567        0.024396               17
# 29           0.861248         0.899567        0.023872               18
# 30           0.867816         0.905475        0.024798                9
# 31           0.865353         0.903998        0.024879               12
# 32           0.862890         0.904325        0.026177               11
# 33           0.866174         0.906295        0.025749                7
# 34           0.865353         0.905310        0.025645               10
# 35           0.863711         0.905802        0.026212                8
# 36           0.807061         0.850666        0.025693               47
# 37           0.800493         0.848204        0.026458               48
# 38           0.811987         0.852471        0.023632               46
# 39           0.829228         0.861334        0.020424               42
# 40           0.827586         0.859693        0.019376               44
# 41           0.819376         0.856574        0.021739               45
# 42           0.827586         0.864615        0.024675               40
# 43           0.831691         0.863959        0.021329               41
# 44           0.830870         0.864615        0.019619               39
# 45           0.818555         0.860840        0.028957               43
# 46           0.830049         0.864943        0.022709               38
# 47           0.833333         0.867405        0.020522               37

# %%
from datetime import datetime
filename = f'gridsearch-results-{datetime.isoformat(datetime.now())}.csv'
resultsDf.to_csv(filename, index=False)

# %%
result.best_estimator_
# Out:
# Pipeline(steps=[('vect',
#                  TfidfVectorizer(max_features=20000, ngram_range=(1, 3),
#                                  preprocessor=<function preprocess at 0x7f3b6f6234d0>,
#                                  stop_words=['de', 'a', 'o', 'que', 'e', 'é',
#                                              'do', 'da', 'em', 'um', 'para',
#                                              'com', 'não', 'uma', 'os', 'no',
#                                              'se', 'na', 'por', 'mais', 'as',
#                                              'dos', 'como', 'mas', 'ao', 'ele',
#                                              'das', 'à', 'seu', 'sua', ...],
#                                  strip_accents=True)),
#                 ('clf', SVC(C=1, probability=True))])

# %%
len(result.best_estimator_.steps[0][1].get_feature_names())
# Out:
# 20000

# %%
xgb = XGBClassifier()
