# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from IPython.display import display
import plotly_express as px
import plotly.io as pio
pio.renderers.default = 'colab'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from datasets import fake_br_corpus

# %%
train = fake_br_corpus.loadTrain(True)
train.head()
# Out:
#                                    author  average sentence length  \
# 0                                    None                   3.0000
# 1                                  Por G1                   5.0000
# 2                                    None                   3.0000
# 3  Guilherme Sobota, O Estado de S. Paulo                  11.8571
# 4                                    None                   3.0000
#
#    average word length             category   date of publication  diversity  \
# 0              5.66667      tv_celebridades            22/10/2016   1.000000
# 1              4.50000      tv_celebridades      06/09/2017 08h34   0.950000
# 2              4.22222             politica            30/01/2017   1.000000
# 3              4.38554  sociedade_cotidiano  17 de agosto de 2017   0.674699
# 4              3.77778             politica            02/02/2017   1.000000
#
#    emotiveness  filename      id label  ...  \
# 0     0.000000  2034.txt  6251.0  fake  ...
# ...

# %%
train['lastChar'] = train.text.apply(lambda text: text.strip()[-1])

# %%
px.histogram(train, x='lastChar', color='label')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
normalized = pd.read_csv('datasets/fake_br_corpus/size_normalized_texts.csv')

# %%
normalized['lastChar'] = normalized.text.apply(lambda text: text.strip()[-1])

# %%
px.histogram(normalized, x='lastChar', color='label')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.pie(train[train.lastChar == '.'], names='label')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.pie(train[train.lastChar != '.'], names='label')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from preprocessing import putEndDot
# Out:
# [nltk_data] Downloading package stopwords to /home/afsm/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
withEndDot = train.copy()
withEndDot['text'] = withEndDot.text.apply(putEndDot)

# %%
withEndDot['lastChar'] = withEndDot.text.apply(lambda text: text.strip()[-1])

# %%
px.histogram(withEndDot, x='lastChar', color='label')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
